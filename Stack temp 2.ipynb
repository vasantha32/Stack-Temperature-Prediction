# %%
import pandas as pd
data=pd.read_csv("/content/drive/MyDrive/dataset/data1.csv")
data=data.dropna()
x=data.iloc[0:,1:25]
y=data.iloc[0:,25:]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)
from sklearn.preprocessing import StandardScaler
st_x= StandardScaler()
x_train= st_x.fit_transform(x_train)
x_test= st_x.transform(x_test)

# %%
#Fitting Decision Tree classifier to the training set
from sklearn.ensemble import RandomForestClassifier
classifier= RandomForestClassifier(n_estimators= 40,max_depth=10, criterion="entropy")
classifier.fit(x_train, y_train)
y_pred= classifier.predict([[311727,3.15,129,4,213,3.34,3.2,7296,23.08,32,24.56,1060,2.99,1.5,112,135,107,130,0,121,2,22.22,21,3.88]])
x_pred= classifier.predict([[315163,3.16,129,4,209,3.35,3.2,7829,23.08,30,24.52,1058,2.99,1.49,120,143,109,128,0,125,1,22.56,21,3.94]])
print(x_pred[0])
print(y_pred[0])
# Out:
# <ipython-input-20-87bd342e1c29>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   classifier.fit(x_train, y_train)
# 99.1
# 99.1

# %%
# !pip install matplotlib-venn

# %%
import pandas as pd
import matplotlib.pyplot as plt
v=["H2",]
data=pd.read_csv("/content/drive/MyDrive/dataset/data1.csv")
data.dropna()
data.plot()
plt.show()

# %%
v=["SKIN_TEMP_AVG"]
# d=pd.read_csv("/content/drive/MyDrive/dataset/data1.csv",usecols=v)
d=pd.read_csv("data.csv",usecols=v)
d.plot()
plt.show()

# %%
v=["SKIN_TEMP_AVG"]
data=pd.read_csv("data.csv")
data.dropna()
data.plot()
plt.ylabel('SKIN_TEMP_AVG')
plt.title('SKIN_TEMP_AVG vs Numaric')
plt.grid(True)
plt.show()
